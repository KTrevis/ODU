# %%
import pandas

# %%
excel = pandas.read_excel("resultats.xlsx", dtype = str)

# %%
excel['Code du b.vote'] = excel['Code du b.vote'].str.slice(1)

# %%
excel = excel[excel['Code du département'] != 'ZZ']
excel = excel[excel['Code du département'] != 'ZX']
excel = excel[excel['Code du département'] != 'ZW']
excel = excel[excel['Code du département'] != 'ZP']
excel = excel[excel['Code du département'] != 'ZN']
#remplace tous les codes de departemet qui ne contiennent pas de chiffres par 97
#excel.loc[~excel['Code du département'].astype(str).str.contains(r'\d', na=False), 'Code du département'] = '97'
#excel.loc[excel['Libellé du département'] == 'Calvados', 'Code du b.vote'] = '14'
#excel.loc[excel['Libellé du département'] == 'Doubs', 'Code du b.vote'] = '25'
#excel.loc[excel['Libellé du département'] == 'Haute-Garonne', 'Code du b.vote'] = '31'
#excel.loc[excel['Libellé du département'] == 'Bas-Rhin', 'Code du b.vote'] = '67'
#excel.loc[excel['Libellé du département'] == 'Paris', 'Code du b.vote'] = '75'
#excel.loc[excel['Libellé du département'] == 'Vaucluse', 'Code du b.vote'] = '84'
(excel[excel['Libellé de la commune'] == 'Caen'])
#excel['Code du b.vote'] = excel['Code du b.vote'].astype('float')
#excel[excel['Code du b.vote'].astype(str).str.contains('\.')]
# Out:
#      Code du département Libellé du département Code de la circonscription  \
# 7944                  14               Calvados                         01
# 7945                  14               Calvados                         01
# 7946                  14               Calvados                         01
# 7947                  14               Calvados                         01
# 7948                  14               Calvados                         01
# 7949                  14               Calvados                         01
# 7950                  14               Calvados                         01
# 7951                  14               Calvados                         01
# 7952                  14               Calvados                         01
# 7953                  14               Calvados                         01
# 7954                  14               Calvados                         01
# ...

# %%
formatted = pandas.DataFrame()
formatted['id_bv'] = excel['Code du département'] + excel['Code de la commune'] + '_' + excel['Code du b.vote']

# %%
formatted
# Out:
#            id_bv
# 0      01001_001
# 1      01002_001
# 2      01004_001
# 3      01004_002
# 4      01004_003
# ...          ...
# 69677  ZZ229_001
# 69678  ZZ231_001
# 69679  ZZ233_001
# 69680  ZZ234_001
# 69681  ZZ235_001
#
# [69682 rows x 1 columns]
